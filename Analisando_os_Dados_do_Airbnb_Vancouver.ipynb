# %% [markdown]
# <a href="https://colab.research.google.com/github/lucmg99/airbnb/blob/main/Analisando_os_Dados_do_Airbnb_Vancouver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SOBRE O AIRBNB**
#
# <img src ="https://raw.githubusercontent.com/lucmg99/airbnb/main/vancouver.jpg?raw=true" width ='120%' >
#
#
# ---
# O [Airbnb](https://https://www.airbnb.com.br/) começou em 2008, quando dois designers que tinham um espaço sobrando hospedaram três viajantes que procuravam um lugar para ficar. Desde então, milhões de anfitriões e hóspedes criaram contas gratuitas no Airbnb para descobrir o mundo e várias culturas de diferentes pontos de vista.
#
# Com esse conceito, o site tonou - se a maior empresa hoteleira da atualidade, com o detalhe de não possuir nenhum hotel!, nenhum patrimonio empresarial para locar.
#
# De casas aconchegantes a coberturas elegantes, os anfitriões ficam felizes em compartilhar seus espaços. Seja uma viagem a trabalho, passeio de fim de semana, férias em família, ou uma estadia mais longa, há milhões de lugares incríveis para visitar.
#
# Além disso, existem as experiências do Airbnb, atividades presenciais ou online oferecidas por especialistas locais inspiradores. De encantadores de cavalos a desfiladeiros para caminhadas, os anfitriões de experiências compartilham a paixão deles por comida, animais, música e muito mais.
#
# Para expedições imersivas, deixe que os guias locais levem você em pequenos grupos por roteiros menos comuns em territórios inexplorados com as Aventuras Airbnb.
#
# Para os profissionais, o Airbnb for Work tem tudo o que é necessário para fazer seu trabalho enquanto viaja, desde lugares com as melhores avaliações e espaços colaborativos até experiências de construção de equipes e ferramentas administrativas que facilitam ainda mais a gestão de viagens.
#
# \
# \
# **FATOS SOBRE O AIRBNB**
#
# *	A Airbnb oferece cerca de 6 milhões de lugares para ficar em todo o mundo.
# *	Brian Chesky e Joe Gebbia estabeleceram o Airbnb em 2008.
# *	A qualquer momento, os hóspedes reservam 1,9 milhão de anúncios no Airbnb.
# *	Airbnb tem escritórios principais em 31 cidades.
# *	Desde seu lançamento, o Airbnb atendeu 400 milhões de hóspedes.
# *	O nome da empresa foi inspirado em uma experiência em que os fundadores alugaram um colchão de ar.
# *	A empresa possui mais de 12.000 funcionários.
# *	Embora a Airbnb seja uma empresa privada, ela está planejando lançar uma oferta pública inicial e se tornar uma empresa de capital aberto no mercado de ações dos EUA em breve.
# *	A empresa é avaliada em US  47 bilhões por investidores do mercado privado.
# *	A sede da Airbnb está localizada em San Francisco, EUA.
# *	Airbnb oferece listagens em mais de 188 países.
# *	Airbnb não tem permissão para operar na Coreia do Norte, Irã, Síria e Crimeia.
# *	Quartos individuais, suítes, apartamentos, casas, barcos-residências e iates fretados são as principais listagens no site.
# *	Tokyo, Paris e Nova York são as cidades mais populares para reservas do Airbnb.
# *	Airbnb lista cerca de 14.000 pequenas casas, 4.000 castelos e 2.400 casas na árvore em seu banco de dados.
# *	Devido ao sucesso da empresa, Brian Chesky foi nomeado uma das "100 pessoas mais influentes" da Time.
# *	Airbnb foi fundada por ex-alunos da Rhode Island School of Design (RISD).
# *	Airbnb cobra 3% do anfitrião por cada reserva.
# *	A empresa registrou 9 milhões de hóspedes atendidos em 2013.
# *	Airbnb atingiu um valor de mercado de US $ 10 bilhões em 2014.
# *	Airbnb levou até 2016 para dar lucro.
#
#
#
# **RASTREABILIDADE DE REQUISITOS**
#
# A rastreabilidade de requisitos é uma técnica utilizada para prover um relacionamento entre os requisitos levantados, a arquitetura do sistema até sua implementação final, possibilitando assim uma compreensão adequada do contexto no qual o software foi construído. A rastreabilidade é identificada como um fator de qualidade, sendo essa uma das características não funcionais do sistema. A rastrebilidade deve possibilitar acompanhar e relatar a vida de um requisito.
#
# \
# \
# <img src ="https://raw.githubusercontent.com/lucmg99/airbnb/main/geral.jpg?raw=true">
#
#
#
#
# **COLABORAÇÃO**
#
# Uma das iniciativas do Airbnb é disponibilizar dados do site, para algumas das principais cidades do mundo. Por meio do portal Inside Airbnb, é possível baixar uma grande quantidade de dados para desenvolver projetos e soluções de Data Science.
#
#
#
# **ESCOLHA**
#
# A  cidade de ***Vancouver*** está sempre em destaque nas listas de melhores cidades para se viver no Canadá, e as razões para isso são bastante evidentes. Com ar puro, opções de transporte público eficientes e áreas verdes, a cidade é projetada para uma vida saudável e sustentável.
#
# \
# \
# ***VISUALIZANDO OS DADOS***
#
# Todos os dados usados aqui foram obtidos a partir do site [Inside Airbnb](http://insideairbnb.com/get-the-data.html).

# %%
# Importando os pacotes necessarios
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
# Importando o arquivo listings.csv para um dataframe
df = pd.read_csv('https://data.insideairbnb.com/canada/bc/vancouver/2023-12-13/visualisations/listings.csv')

# %% [markdown]
# ***Análisando os dados***
#
# Essa etapa permite um entendimento melhor de como os dados estão estruturados.
#
# * `id` - número de id gerado para identificar o imóvel;
# * `name` - nome da propriedade anunciada;
# * `host_id` - número de id do proprietário (anfitrião) da propriedade;
# * `host_name` - Nome do anfitrião;
# * `neighbourhood_group` - esta coluna não contém nenhum valor válido;
# * `neighbourhood` - nome do bairro;
# * `latitude` - coordenada da latitude da propriedade;
# * `longitude` - coordenada da longitude da propriedade;
# * `room_type` - informa o tipo de quarto que é oferecido;
# * `price` - preço para alugar o imóvel;
# * `minimum_nights` - quantidade mínima de noites para reservar;
# * `number_of_reviews` - número de reviews que a propriedade possui;
# * `last_review` - data do último review;
# * `reviews_per_month` - quantidade de reviews por mês;
# * `calculated_host_listings_count` - quantidade de imóveis do mesmo anfitrião;
# * `availability_365` - número de dias de disponibilidade dentro de 365 dias.
#
#
#
# Com o intuito de melhorar a vizualização dos dados, vamos traduzir a linguagem das colunas (Variáveis) para o português.

# %%
# Trocando o nome das Colunas
df.rename(columns = {'id': 'id_imovel','name':'logradouro','host_id':'id_proprietario','host_name':'proprietario','neighbourhood_group':'grupo_bairro','neighbourhood':'bairro','room_type':'tipo_quarto',
                     'price':'preço','minimum_nights':'minimo_noite','number_of_reviews':'numero_reviews','last_review':'ultimo_review','reviews_per_month':'reviews_mensal',
                     'calculated_host_listings_count':'imoveis_proprietario','availability_365':'disponibilidade_anual'} ,inplace=True)

# %%
# Removendo Colunas com dados desnecessarios
df = df.drop(['license','number_of_reviews_ltm'],axis = 1)

# %%
# Mostrando as 5 Primeiras entradas do DataSet
df.head()
# Out:
#    id_imovel                                         logradouro  \
# 0      13188  Rental unit in Vancouver · ★4.84 · Studio · 2 ...
# 1      13221  Rental unit in Vancouver · ★4.73 · 1 bedroom ·...
# 2      13358  Condo in Vancouver · ★4.68 · 1 bedroom · 1 bed...
# 3      13490  Rental unit in Vancouver · ★4.93 · 1 bedroom ·...
# 4      14267  Home in Vancouver · ★4.76 · 1 bedroom · 2 beds...
#
#    id_proprietario    proprietario  grupo_bairro                    bairro  \
# 0            51466    Ian And Emma           NaN                Riley Park
# 1            51634          Amanda           NaN                Riley Park
# 2            52116            Lynn           NaN                  Downtown
# 3            52467            Iris           NaN  Kensington-Cedar Cottage
# 4            56030  Peter & Alison           NaN  Kensington-Cedar Cottage
#
#     latitude   longitude      tipo_quarto  preço  minimo_noite  \
# ...

# %% [markdown]
# ### **Q1. Quantos atributos (variáveis) e quantas entradas o nosso conjunto de dados possui? Quais os tipos das variáveis?**

# %%
# Identificar o valume de dados do DataFrame
print('Entradas:\t {}'.format(df.shape[0]))
print('Variaveis:\t {}'.format(df.shape[1]))

# Verificar quais os tipos de variaveis
print('\t')
df.dtypes
# Out:
# Entradas:	 6691
# Variaveis:	 16
# id_imovel                  int64
# logradouro                object
# id_proprietario            int64
# proprietario              object
# grupo_bairro             float64
# bairro                    object
# latitude                 float64
# longitude                float64
# tipo_quarto               object
# preço                    float64
# minimo_noite               int64
# numero_reviews             int64
# ultimo_review             object
# reviews_mensal           float64
# imoveis_proprietario       int64
# disponibilidade_anual      int64
# dtype: object

# %% [markdown]
# ### **Q2. Qual a porcentagem de valores ausentes no *dataset*?**
# A qualidade de um *dataset* está diretamente relacionada à quantidade de valores ausentes. É importante entender logo no início se esses valores nulos são significativos comparados ao total de entradas.
# * A coluna `neighbourhood_group` possui 100% dos seus valores faltantes.
# * As variáveis `reviews_per_month` e `last_review` possuem valores nulos em quase metade das linhas.
# * As variáveis `name` e `host_name` tem aproximadamente 0,1% dos valores nulos.

# %%
# Ordenar em ordem decrescente as variáveis por seus valores ausentes
(df.isnull().sum() / df.shape[0]).sort_values(ascending=False)
# Out:
# grupo_bairro             1.000000
# ultimo_review            0.170229
# reviews_mensal           0.170229
# preço                    0.125542
# id_imovel                0.000000
# logradouro               0.000000
# id_proprietario          0.000000
# proprietario             0.000000
# bairro                   0.000000
# latitude                 0.000000
# longitude                0.000000
# tipo_quarto              0.000000
# minimo_noite             0.000000
# numero_reviews           0.000000
# imoveis_proprietario     0.000000
# disponibilidade_anual    0.000000
# dtype: float64

# %% [markdown]
# ### **Q3. Qual o tipo de distribuição das variáveis?**
#
# Vamos plotar um histograma para identificar as disribuições das variáveis.

# %%
# plotar o histograma das variáveis numéricas
df.hist(bins=15, grid = False ,figsize=(15,10));

# %% [markdown]
# A media do aluguei é `C$201` Dólares Canadense, convertendo para o real ficamos com o valor aproximado de `R$755,22`.

# %%
# Vendo a media da coluna Preço
df.preço.mean()
# Out:
# 201.01264741069903

# %% [markdown]
# ### **Q4.Há outliers presentes?**
# Pela distribuição do histograma, é possível verificar indícios da presença de *outliers*. Olhe por exemplo as variáveis `preço`, `minimo_noite`,  `imoveis_proprietario` e `numero_reviews`.
#
# Os valores não seguem uma distruição, e distorcem toda a representação gráfica. Para confirmar, há duas maneiras rápidas que auxiliam a detecção de *outliers*. São elas:
#
# * Resumo estatístico por meio do método `describe()`
# * Plotar `boxplots` para a variável.

# %%
# ver o resumo estatístico das variáveis numéricas
df[['preço','minimo_noite','imoveis_proprietario','numero_reviews']].describe()
# Out:
#               preço  minimo_noite  imoveis_proprietario  numero_reviews
# count   5851.000000   6691.000000           6691.000000     6691.000000
# mean     201.012647     16.129726              6.933343       40.307278
# std      546.121150     28.709975             19.886758       72.113204
# min       14.000000      1.000000              1.000000        0.000000
# 25%      100.000000      2.000000              1.000000        2.000000
# 50%      139.000000      3.000000              1.000000       11.000000
# 75%      204.000000     30.000000              3.000000       49.000000
# max    28650.000000    399.000000            134.000000      948.000000

# %% [markdown]
# Olhando o resumo estatístico acima, podemos confirmar algumas hipóteses como:
#
# * A variável `price` possui 75% do valor abaixo de `$204,00`, porém seu valor máximo é `$28650,00`.
# * A quantidade mínima de noites (`minimum_nights`) está acima de 365 dias no ano.
# * Vaor minimo de aluguel está `$14,00`
#
# #### Boxplot para minimum_nights

# %%
# minimum_nights
df.minimo_noite.plot(kind='box', vert=False, figsize=(15, 3))
plt.show()

# ver quantidade de valores acima de 30 dias para minimum_nights
print("Minimo noite: valores acima de 30:")
print("{} entradas".format(len(df[df.minimo_noite > 30])))
print("{:.4f}%".format((len(df[df.minimo_noite > 30]) / df.shape[0])*100))
# Out:
# Minimo noite: valores acima de 30:
# 385 entradas
# 5.7540%

# %% [markdown]
# #### Boxplot para price

# %%
# price
df.preço.plot(kind='box', vert=False, figsize=(15, 3),)
plt.show()

# ver quantidade de valores acima de 8000 para price
print("\npreço: valores acima de 8000")
print("{} entradas".format(len(df[df.preço > 8000])))
print("{:.4f}%".format((len(df[df.preço > 8000]) / df.shape[0])*100))

# df.price.plot(kind='box', vert=False, xlim=(0,1300), figsize=(15,3));
# Out:
# preço: valores acima de 8000
# 6 entradas
# 0.0897%

# %% [markdown]
# ### **Q4. Qual a correlação existente entre as variáveis**
#
# Correlação significa que existe uma relação entre duas coisas. No nosso contexto, estamos buscando relação ou semelhança entre duas variáveis.
#
# Essa relação pode ser medida, e é função do coeficiente de correlação estabelecer qual a intensidade dela. Para identificar as correlações existentes entre as variáveis de interesse, vou:
#
# * Criar uma matriz de correlação
# * Gerar um *heatmap* a partir dessa matriz, usando a biblioteca `seaborn`

# %%
# criar uma matriz de correlação
corr = df[['preço','minimo_noite', 'numero_reviews','imoveis_proprietario','disponibilidade_anual','reviews_mensal']].corr()
# mostrar a matriz de correlação
display(corr)
# Out:
#                           preço  minimo_noite  numero_reviews  \
# preço                  1.000000      0.001994       -0.039338
# minimo_noite           0.001994      1.000000       -0.170764
# numero_reviews        -0.039338     -0.170764        1.000000
# imoveis_proprietario  -0.012038      0.072437       -0.108751
# disponibilidade_anual  0.068647      0.159536       -0.116816
# reviews_mensal        -0.043224     -0.324344        0.483418
#
#                        imoveis_proprietario  disponibilidade_anual  \
# preço                             -0.012038               0.068647
# minimo_noite                       0.072437               0.159536
# numero_reviews                    -0.108751              -0.116816
# imoveis_proprietario               1.000000               0.159767
# disponibilidade_anual              0.159767               1.000000
# reviews_mensal                    -0.091017              -0.137895
#
#                        reviews_mensal
# ...

# %%
# Plotar um heatmap a partir de correlações
sns.heatmap(corr, cmap='RdBu', fmt='.2f', square=True, linecolor='white', annot=True);

# %% [markdown]
# ### **Q5. Qual o tipo de imóvel mais alugado no Airbnb?**

# %%
# Removendo os Outliers em um novo DataFrame
df_clean = df.copy()
df_clean.drop(df_clean[df_clean.preço > 8000].index, axis=0, inplace = True)
df_clean.drop(df_clean[df_clean.minimo_noite > 30 ].index, axis=0, inplace = True)

# Removendo neighbourhood_group, pois está vazio
df_clean.drop('grupo_bairro', axis=1, inplace = True)

# %%
# Mostrar a quantidade de cada tipo de Imóvel disponivel
room_type_group = df_clean.tipo_quarto.value_counts()
room_type_group
# Out:
# tipo_quarto
# Entire home/apt    5070
# Private room       1213
# Shared room          14
# Hotel room            3
# Name: count, dtype: int64

# %%
# Mostrar a porcentagem de cada tipo de imóvel disponível

df_clean.tipo_quarto.value_counts()/df_clean.shape[0]*100
# Out:
# tipo_quarto
# Entire home/apt    80.476190
# Private room       19.253968
# Shared room         0.222222
# Hotel room          0.047619
# Name: count, dtype: float64

# %%
df_clean.bairro.value_counts()
# Out:
# bairro
# Downtown                    1597
# Kitsilano                    457
# West End                     456
# Mount Pleasant               410
# Kensington-Cedar Cottage     397
# Downtown Eastside            353
# Riley Park                   292
# Grandview-Woodland           265
# Hastings-Sunrise             262
# Renfrew-Collingwood          229
# Dunbar Southlands            204
# Marpole                      179
# Fairview                     171
# Sunset                       167
# Victoria-Fraserview          159
# Oakridge                     128
# Arbutus Ridge                114
# West Point Grey              111
# Shaughnessy                   87
# Killarney                     81
# Kerrisdale                    78
# South Cambie                  68
# Strathcona                    35
# Name: count, dtype: int64

# %% [markdown]
# ### **Q6. Qual a localidade mais cara do dataset?**

# %%
# Média de preço por bairro, as 5 Maiores
df_clean.groupby(['bairro']).preço.mean().sort_values(ascending = False)[:5]
# Out:
# bairro
# Kitsilano          228.619898
# Kerrisdale         220.750000
# Downtown           217.297843
# West Point Grey    216.092784
# Arbutus Ridge      203.284314
# Name: preço, dtype: float64

# %%
# Ver a quantidade de imóveis no Kitsilano
print(df_clean[df_clean.bairro == "Kitsilano"].shape)

# Ver as 3 entradas do Kitsilano
df_clean[df_clean.bairro == "Kitsilano"] [:3]
# Out:
# (457, 15)
#     id_imovel                                         logradouro  \
# 16      24273  Rental unit in Vancouver · ★5.0 · 2 bedrooms ·...
# 30     182451  Guest suite in Vancouver · ★4.88 · 1 bedroom ·...
# 32     219261  Rental unit in Vancouver · ★4.60 · 2 bedrooms ...
#
#     id_proprietario proprietario     bairro  latitude  longitude  \
# 16          1267409        Julia  Kitsilano  49.26216 -123.17150
# 30           874660        Penny  Kitsilano  49.25808 -123.16824
# 32          1135259         Rami  Kitsilano  49.27190 -123.15043
#
#         tipo_quarto  preço  minimo_noite  numero_reviews ultimo_review  \
# 16  Entire home/apt  150.0            30              17    2023-11-05
# 30  Entire home/apt  131.0            30              58    2023-12-01
# 32  Entire home/apt  123.0            30             256    2023-10-31
#
#     reviews_mensal  imoveis_proprietario  disponibilidade_anual
# 16            0.13                     2                    242
# ...

# %%
# Plotando os imóveis pela latitude-longitude
df_clean.plot(kind="scatter", x='longitude', y='latitude', alpha=0.4, c=df_clean['preço'], s=8,
              cmap=plt.get_cmap('jet'), figsize=(12,8));

# %% [markdown]
# ### **Q7. Qual é a média do mínimo de noites para aluguel (minimum_nights)?**

# %%
df_clean.minimo_noite.mean()
# Out:
# 11.7984126984127

# %% [markdown]
# ## ***Conclusões***
#
#
# Foram realizadas apenas umas análises superficiais na base de dados do Airbnb, porém  percebe se que existem *outliers* em algumas das variáveis.
#
# Por fim, lembra-se que este *dataset* é uma versão resumida, ideal apenas para uma abordagem inicial. Recomenda-se que seja usado, em uma próxima análise exploratória.
